# %%
from OFDM_Models import *
import pandas as pd

# %%
from keras.layers import Add, MaxPooling2D, Activation
from tensorflow.keras.layers import Input, Conv1D, Activation, BatchNormalization, Add, Dense,MaxPooling1D,Flatten,Dropout,MaxPooling2D
from tensorflow.keras.layers import Layer, Conv2D, Conv1D, Flatten, Dense, Reshape, Conv2DTranspose,Concatenate
from tensorflow import keras
from keras.regularizers import l2


def TRSN1_(input_layer):
    conv = ConvRFF(output_dim=32,kernel_size=(1,1), padding='SAME', activation="linear")(input_layer)
    conv1 = ConvRFF(output_dim=32, kernel_size=(3,2), padding='SAME', activation="relu")(conv)
    res1 = Add()([conv, conv1])
    conv2 = Conv2D(32, (3,2), padding='same', activation="relu")(res1)
    conv4 = Conv2D(32, (3,2), padding='same', activation="relu")(conv2)
    res2 = Add()([res1, conv4])
    conv5 = Conv2D(32, (3,2), padding='same', activation="relu")(res2)
    conv6 = Conv2D(32, (3,2), padding='same', activation="relu")(conv5)
    conv7 = Conv2D(32, (3,2), padding='same', activation="relu")(conv6)
    res3 = Add()([conv4, conv7])
    res4 = Add()([res3, conv])
    max_pool = MaxPooling2D(pool_size=(2,2))(res4)
    return max_pool

def TRSN(input_layer):
    conv = Conv2D(32, (1,1), padding='SAME', activation="linear")(input_layer)
    conv1 = Conv2D(32, (3,1), padding='SAME', activation="relu")(conv)
    res1 = Add()([conv, conv1])
    conv2 = Conv2D(32, (3,1), padding='same', activation="relu")(res1)
    conv4 = Conv2D(32, (3,1), padding='same', activation="relu")(conv2)
    res2 = Add()([res1, conv4])
    conv5 = Conv2D(32, (3,1), padding='same', activation="relu")(res2)
    conv6 = Conv2D(32, (3,1), padding='same', activation="relu")(conv5)
    conv7 = Conv2D(32, (3,1), padding='same', activation="relu")(conv6)
    res3 = Add()([conv4, conv7])
    res4 = Add()([res3, conv])
    max_pool = MaxPooling2D(pool_size=(2,1))(res4)
    return max_pool

# %%
tf.keras.backend.clear_session()
#tf.debugging.experimental.enable_dump_debug_info(
#    "./logs/debug", tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1
#)
# Define input shape with complex numbers
input_shape = (512, 2,1)

# Define input layer for complex data

input_layer = Input(shape=input_shape)

TRSN1 = TRSN1_(input_layer)
TRSN2= TRSN(TRSN1)
TRSN3= TRSN(TRSN2)
TRSN4= TRSN(TRSN3)
TRSN5= TRSN(TRSN4)
TRSN6= TRSN(TRSN5)
TRSN7= TRSN(TRSN6)


flatten = Flatten()(TRSN7)

fc = Dense(128, activation='selu')(flatten)
dropout =Dropout(0.3)(fc)
output = Dense(6, activation='softmax')(dropout)

# Define the model
model = keras.Model(inputs=input_layer, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 2, 1)]          0         []
#
#  conv_rff (ConvRFF)          (None, 512, 2, 32)           65        ['input_1[0][0]']
#
#  conv_rff_1 (ConvRFF)        (None, 512, 2, 32)           6177      ['conv_rff[0][0]']
#
#  add (Add)                   (None, 512, 2, 32)           0         ['conv_rff[0][0]',
#                                                                      'conv_rff_1[0][0]']
#
#  conv2d (Conv2D)             (None, 512, 2, 32)           6176      ['add[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d[0][0]']
#
#  add_1 (Add)                 (None, 512, 2, 32)           0         ['add[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 512, 2, 32)           6176      ['add_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d_3[0][0]']
#
#  add_2 (Add)                 (None, 512, 2, 32)           0         ['conv2d_1[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  add_3 (Add)                 (None, 512, 2, 32)           0         ['add_2[0][0]',
#                                                                      'conv_rff[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 1, 32)           0         ['add_3[0][0]']
#  D)
#
#  conv2d_5 (Conv2D)           (None, 256, 1, 32)           1056      ['max_pooling2d[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 256, 1, 32)           3104      ['conv2d_5[0][0]']
#
#  add_4 (Add)                 (None, 256, 1, 32)           0         ['conv2d_5[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 256, 1, 32)           3104      ['add_4[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 1, 32)           3104      ['conv2d_7[0][0]']
#
#  add_5 (Add)                 (None, 256, 1, 32)           0         ['add_4[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 1, 32)           3104      ['add_5[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 1, 32)           3104      ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 256, 1, 32)           3104      ['conv2d_10[0][0]']
#
#  add_6 (Add)                 (None, 256, 1, 32)           0         ['conv2d_8[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  add_7 (Add)                 (None, 256, 1, 32)           0         ['add_6[0][0]',
#                                                                      'conv2d_5[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 1, 32)           0         ['add_7[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 128, 1, 32)           1056      ['max_pooling2d_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_12[0][0]']
#
#  add_8 (Add)                 (None, 128, 1, 32)           0         ['conv2d_12[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 1, 32)           3104      ['add_8[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_14[0][0]']
#
#  add_9 (Add)                 (None, 128, 1, 32)           0         ['add_8[0][0]',
#                                                                      'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 1, 32)           3104      ['add_9[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_17[0][0]']
#
#  add_10 (Add)                (None, 128, 1, 32)           0         ['conv2d_15[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  add_11 (Add)                (None, 128, 1, 32)           0         ['add_10[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 1, 32)            0         ['add_11[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 64, 1, 32)            1056      ['max_pooling2d_2[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_19[0][0]']
#
#  add_12 (Add)                (None, 64, 1, 32)            0         ['conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 64, 1, 32)            3104      ['add_12[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_21[0][0]']
#
#  add_13 (Add)                (None, 64, 1, 32)            0         ['add_12[0][0]',
#                                                                      'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 1, 32)            3104      ['add_13[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_24[0][0]']
#
#  add_14 (Add)                (None, 64, 1, 32)            0         ['conv2d_22[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  add_15 (Add)                (None, 64, 1, 32)            0         ['add_14[0][0]',
#                                                                      'conv2d_19[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 1, 32)            0         ['add_15[0][0]']
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 32, 1, 32)            1056      ['max_pooling2d_3[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_26[0][0]']
#
#  add_16 (Add)                (None, 32, 1, 32)            0         ['conv2d_26[0][0]',
#                                                                      'conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 32, 1, 32)            3104      ['add_16[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_28[0][0]']
#
#  add_17 (Add)                (None, 32, 1, 32)            0         ['add_16[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 32, 1, 32)            3104      ['add_17[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_31[0][0]']
#
#  add_18 (Add)                (None, 32, 1, 32)            0         ['conv2d_29[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  add_19 (Add)                (None, 32, 1, 32)            0         ['add_18[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 1, 32)            0         ['add_19[0][0]']
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 16, 1, 32)            1056      ['max_pooling2d_4[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_33[0][0]']
#
#  add_20 (Add)                (None, 16, 1, 32)            0         ['conv2d_33[0][0]',
#                                                                      'conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 16, 1, 32)            3104      ['add_20[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_35[0][0]']
#
#  add_21 (Add)                (None, 16, 1, 32)            0         ['add_20[0][0]',
#                                                                      'conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 16, 1, 32)            3104      ['add_21[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_38[0][0]']
#
#  add_22 (Add)                (None, 16, 1, 32)            0         ['conv2d_36[0][0]',
#                                                                      'conv2d_39[0][0]']
#
#  add_23 (Add)                (None, 16, 1, 32)            0         ['add_22[0][0]',
#                                                                      'conv2d_33[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 1, 32)             0         ['add_23[0][0]']
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 8, 1, 32)             1056      ['max_pooling2d_5[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_40[0][0]']
#
#  add_24 (Add)                (None, 8, 1, 32)             0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 8, 1, 32)             3104      ['add_24[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_42[0][0]']
#
#  add_25 (Add)                (None, 8, 1, 32)             0         ['add_24[0][0]',
#                                                                      'conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 8, 1, 32)             3104      ['add_25[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_45[0][0]']
#
#  add_26 (Add)                (None, 8, 1, 32)             0         ['conv2d_43[0][0]',
#                                                                      'conv2d_46[0][0]']
#
#  add_27 (Add)                (None, 8, 1, 32)             0         ['add_26[0][0]',
#                                                                      'conv2d_40[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 1, 32)             0         ['add_27[0][0]']
#  g2D)
#
#  flatten (Flatten)           (None, 128)                  0         ['max_pooling2d_6[0][0]']
#
#  dense (Dense)               (None, 128)                  16512     ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 6)                    774       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 172488 (673.78 KB)
# Trainable params: 166246 (649.40 KB)
# Non-trainable params: 6242 (24.38 KB)
# __________________________________________________________________________________________________

# %%
X_train = np.load("DATASETS/X_train.npy",allow_pickle=True)
y_train_onehot = np.load("DATASETS/y_train_onehot.npy",allow_pickle=True)
y_test = np.load("DATASETS/y_test.npy",allow_pickle=True)
X_test = pd.read_hdf("DATASETS/test_data.h5",key="test")
# Out:
# /tmp/ipykernel_12058/2731762193.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_test = pd.read_hdf("DATASETS/test_data.h5",key="test")

# %%
X_train = X_train[:, :512, :]

# %%
import tensorflow_addons as tfa

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="checkpoints/",
    save_weights_only=True,
    monitor='val_f1_score',  # Changed from 'val_acc' to 'val_accuracy'
    mode='max',
    save_best_only=True)

# EarlyStopping callback to stop training when overfitting is detected
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True)  # Restore model weights from the epoch with the best value of the monitored quantity

model.compile(optimizer="adam",loss='categorical_crossentropy', metrics=[tfa.metrics.F1Score(num_classes=6, average='macro')])

batch_size = 1024
epochs = 150
history = model.fit(X_train, y_train_onehot, batch_size=batch_size, epochs=epochs,
                    callbacks=[tensorboard_callback, model_checkpoint_callback, early_stopping_callback],
                    validation_split=0.3)
# Out:
# Epoch 1/150
# 171/171 [==============================] - 53s 237ms/step - loss: 1.8015 - f1_score: 0.1718 - val_loss: 1.7665 - val_f1_score: 0.1747
# Epoch 2/150
# 171/171 [==============================] - 39s 229ms/step - loss: 1.6500 - f1_score: 0.2487 - val_loss: 1.2936 - val_f1_score: 0.3850
# Epoch 3/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.7338 - f1_score: 0.6840 - val_loss: 0.4812 - val_f1_score: 0.7858
# Epoch 4/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.3948 - f1_score: 0.8307 - val_loss: 0.3358 - val_f1_score: 0.8541
# Epoch 5/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.3339 - f1_score: 0.8530 - val_loss: 0.3181 - val_f1_score: 0.8583
# Epoch 6/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.3092 - f1_score: 0.8641 - val_loss: 0.3064 - val_f1_score: 0.8648
# Epoch 7/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2971 - f1_score: 0.8690 - val_loss: 0.3158 - val_f1_score: 0.8631
# Epoch 8/150
# 171/171 [==============================] - 40s 232ms/step - loss: 0.2866 - f1_score: 0.8740 - val_loss: 0.2923 - val_f1_score: 0.8716
# Epoch 9/150
# 171/171 [==============================] - 40s 232ms/step - loss: 0.2785 - f1_score: 0.8764 - val_loss: 0.2740 - val_f1_score: 0.8795
# Epoch 10/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.2690 - f1_score: 0.8814 - val_loss: 0.2856 - val_f1_score: 0.8774
# Epoch 11/150
# 171/171 [==============================] - 40s 232ms/step - loss: 0.2655 - f1_score: 0.8845 - val_loss: 0.2632 - val_f1_score: 0.8853
# Epoch 12/150
# 171/171 [==============================] - 40s 232ms/step - loss: 0.2577 - f1_score: 0.8883 - val_loss: 0.2647 - val_f1_score: 0.8857
# Epoch 13/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.2557 - f1_score: 0.8888 - val_loss: 0.2643 - val_f1_score: 0.8854
# Epoch 14/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.2479 - f1_score: 0.8932 - val_loss: 0.2718 - val_f1_score: 0.8823
# Epoch 15/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2448 - f1_score: 0.8937 - val_loss: 0.2542 - val_f1_score: 0.8908
# Epoch 16/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2382 - f1_score: 0.8971 - val_loss: 0.2572 - val_f1_score: 0.8922
# Epoch 17/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.2377 - f1_score: 0.8983 - val_loss: 0.2639 - val_f1_score: 0.8883
# Epoch 18/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2325 - f1_score: 0.9003 - val_loss: 0.2556 - val_f1_score: 0.8937
# Epoch 19/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2406 - f1_score: 0.8975 - val_loss: 0.2559 - val_f1_score: 0.8889
# Epoch 20/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2209 - f1_score: 0.9065 - val_loss: 0.2574 - val_f1_score: 0.8912
# Epoch 21/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.2230 - f1_score: 0.9048 - val_loss: 0.2590 - val_f1_score: 0.8905
# Epoch 22/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2179 - f1_score: 0.9075 - val_loss: 0.2616 - val_f1_score: 0.8916
# Epoch 23/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.2113 - f1_score: 0.9101 - val_loss: 0.2489 - val_f1_score: 0.8950
# Epoch 24/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2222 - f1_score: 0.9057 - val_loss: 0.2693 - val_f1_score: 0.8910
# Epoch 25/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2056 - f1_score: 0.9131 - val_loss: 0.2462 - val_f1_score: 0.8963
# Epoch 26/150
# 171/171 [==============================] - 39s 231ms/step - loss: 0.2031 - f1_score: 0.9136 - val_loss: 0.2491 - val_f1_score: 0.8969
# Epoch 27/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.2070 - f1_score: 0.9133 - val_loss: 0.2728 - val_f1_score: 0.8846
# Epoch 28/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.2007 - f1_score: 0.9153 - val_loss: 0.2464 - val_f1_score: 0.8971
# Epoch 29/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1958 - f1_score: 0.9177 - val_loss: 0.2501 - val_f1_score: 0.8964
# Epoch 30/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1931 - f1_score: 0.9193 - val_loss: 0.2483 - val_f1_score: 0.8969
# Epoch 31/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.1937 - f1_score: 0.9195 - val_loss: 0.2548 - val_f1_score: 0.8977
# Epoch 32/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1965 - f1_score: 0.9178 - val_loss: 0.2498 - val_f1_score: 0.8995
# Epoch 33/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1866 - f1_score: 0.9218 - val_loss: 0.2542 - val_f1_score: 0.8956
# Epoch 34/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1860 - f1_score: 0.9231 - val_loss: 0.2607 - val_f1_score: 0.8964
# Epoch 35/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1833 - f1_score: 0.9245 - val_loss: 0.2442 - val_f1_score: 0.9008
# Epoch 36/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1837 - f1_score: 0.9241 - val_loss: 0.2517 - val_f1_score: 0.9005
# Epoch 37/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1757 - f1_score: 0.9269 - val_loss: 0.2534 - val_f1_score: 0.8978
# Epoch 38/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1893 - f1_score: 0.9228 - val_loss: 0.2515 - val_f1_score: 0.8979
# Epoch 39/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1830 - f1_score: 0.9245 - val_loss: 0.2461 - val_f1_score: 0.9014
# Epoch 40/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1647 - f1_score: 0.9318 - val_loss: 0.2572 - val_f1_score: 0.9007
# Epoch 41/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1643 - f1_score: 0.9325 - val_loss: 0.2537 - val_f1_score: 0.9030
# Epoch 42/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1685 - f1_score: 0.9309 - val_loss: 0.2557 - val_f1_score: 0.8987
# Epoch 43/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1641 - f1_score: 0.9327 - val_loss: 0.2675 - val_f1_score: 0.8957
# Epoch 44/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1613 - f1_score: 0.9333 - val_loss: 0.2561 - val_f1_score: 0.9021
# Epoch 45/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1689 - f1_score: 0.9308 - val_loss: 0.2654 - val_f1_score: 0.8975
# Epoch 46/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1610 - f1_score: 0.9341 - val_loss: 0.2764 - val_f1_score: 0.9018
# Epoch 47/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1558 - f1_score: 0.9363 - val_loss: 0.2623 - val_f1_score: 0.9008
# Epoch 48/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1782 - f1_score: 0.9280 - val_loss: 0.2535 - val_f1_score: 0.9017
# Epoch 49/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1512 - f1_score: 0.9385 - val_loss: 0.2773 - val_f1_score: 0.8998
# Epoch 50/150
# 171/171 [==============================] - 39s 227ms/step - loss: 0.1495 - f1_score: 0.9392 - val_loss: 0.3160 - val_f1_score: 0.8936
# Epoch 51/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1528 - f1_score: 0.9376 - val_loss: 0.2822 - val_f1_score: 0.9015
# Epoch 52/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1522 - f1_score: 0.9385 - val_loss: 0.2846 - val_f1_score: 0.9007
# Epoch 53/150
# 171/171 [==============================] - 39s 227ms/step - loss: 0.1405 - f1_score: 0.9428 - val_loss: 0.2772 - val_f1_score: 0.8998
# Epoch 54/150
# 171/171 [==============================] - 39s 228ms/step - loss: 0.1660 - f1_score: 0.9335 - val_loss: 0.2719 - val_f1_score: 0.9006
# Epoch 55/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.1426 - f1_score: 0.9422 - val_loss: 0.2760 - val_f1_score: 0.9007
# Epoch 56/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1389 - f1_score: 0.9441 - val_loss: 0.2816 - val_f1_score: 0.9004
# Epoch 57/150
# 171/171 [==============================] - 39s 230ms/step - loss: 0.1470 - f1_score: 0.9415 - val_loss: 0.2856 - val_f1_score: 0.8986
# Epoch 58/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1383 - f1_score: 0.9443 - val_loss: 0.2722 - val_f1_score: 0.9002
# Epoch 59/150
# 171/171 [==============================] - 39s 229ms/step - loss: 0.1502 - f1_score: 0.9411 - val_loss: 0.2867 - val_f1_score: 0.8886
# Epoch 60/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1492 - f1_score: 0.9401Restoring model weights from the end of the best epoch: 35.
# 171/171 [==============================] - 39s 230ms/step - loss: 0.1492 - f1_score: 0.9401 - val_loss: 0.2974 - val_f1_score: 0.9011
# Epoch 60: early stopping

# %%
model.save("RFF_512.h5")
