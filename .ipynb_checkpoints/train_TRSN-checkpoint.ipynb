# %%
from OFDM_Models import *
import pandas as pd
# Out:
# 2024-03-03 22:53:36.198583: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-03 22:53:36.254651: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 22:53:36.254683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 22:53:36.256786: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 22:53:36.267214: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-03 22:53:37.221781: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from keras.layers import Add, MaxPooling2D, Activation
from tensorflow.keras.layers import Input, Conv1D, Activation, BatchNormalization, Add, Dense,MaxPooling1D,Flatten,Dropout,MaxPooling2D
from tensorflow.keras.layers import Layer, Conv2D, Conv1D, Flatten, Dense, Reshape, Conv2DTranspose,Concatenate
from tensorflow import keras
from keras.regularizers import l2


def TRSN1_(input_layer):
    conv = Conv2D(32, (1,1), padding='SAME', activation="linear")(input_layer)
    conv1 = Conv2D(32, (3,2), padding='same', activation="relu")(conv)
    res1 = Add()([conv, conv1])
    conv2 = Conv2D(32, (3,2), padding='same', activation="relu")(res1)
    conv4 = Conv2D(32, (3,2), padding='same', activation="relu")(conv2)
    res2 = Add()([res1, conv4])
    conv5 = Conv2D(32, (3,2), padding='same', activation="relu")(res2)
    conv6 = Conv2D(32, (3,2), padding='same', activation="relu")(conv5)
    conv7 = Conv2D(32, (3,2), padding='same', activation="relu")(conv6)
    res3 = Add()([conv4, conv7])
    res4 = Add()([res3, conv])
    max_pool = MaxPooling2D(pool_size=(2,2))(res4)
    return max_pool

def TRSN(input_layer):
    conv = Conv2D(32, (1,1), padding='same', activation="linear")(input_layer)
    conv1 = Conv2D(32, (3,1), padding='same', activation="relu")(conv)
    res1 = Add()([conv, conv1])
    conv2 = Conv2D(32, (3,1), padding='same', activation="relu")(res1)
    conv4 = Conv2D(32, (3,1), padding='same', activation="relu")(conv2)
    res2 = Add()([res1, conv4])
    conv5 = Conv2D(32, (3,1), padding='same', activation="relu")(res2)
    conv6 = Conv2D(32, (3,1), padding='same', activation="relu")(conv5)
    conv7 = Conv2D(32, (3,1), padding='same', activation="relu")(conv6)
    res3 = Add()([conv4, conv7])
    res4 = Add()([res3, conv])
    max_pool = MaxPooling2D(pool_size=(2,1))(res4)
    return max_pool

# %%
tf.keras.backend.clear_session()
#tf.debugging.experimental.enable_dump_debug_info(
#    "./logs/debug", tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1
#)
# Define input shape with complex numbers
input_shape = (512, 2,1)

# Define input layer for complex data

input_layer = Input(shape=input_shape)

TRSN1 = TRSN1_(input_layer)
TRSN2= TRSN(TRSN1)
TRSN3= TRSN(TRSN2)
TRSN4= TRSN(TRSN3)
TRSN5= TRSN(TRSN4)
TRSN6= TRSN(TRSN5)
TRSN7= TRSN(TRSN6)


flatten = Flatten()(TRSN7)

fc = Dense(128, activation='selu')(flatten)
dropout =Dropout(0.3)(fc)
output = Dense(6, activation='softmax')(dropout)

# Define the model
model = keras.Model(inputs=input_layer, outputs=output)
# Out:
# 2024-03-03 22:53:38.898736: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:38.976984: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:38.980456: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:38.984189: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:38.987447: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:38.990496: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:39.156155: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:39.157411: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:39.158585: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-03 22:53:39.159670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 2, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 512, 2, 32)           64        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d[0][0]']
#
#  add (Add)                   (None, 512, 2, 32)           0         ['conv2d[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 512, 2, 32)           6176      ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d_2[0][0]']
#
#  add_1 (Add)                 (None, 512, 2, 32)           0         ['add[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 512, 2, 32)           6176      ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 512, 2, 32)           6176      ['conv2d_5[0][0]']
#
#  add_2 (Add)                 (None, 512, 2, 32)           0         ['conv2d_3[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  add_3 (Add)                 (None, 512, 2, 32)           0         ['add_2[0][0]',
#                                                                      'conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 1, 32)           0         ['add_3[0][0]']
#  D)
#
#  conv2d_7 (Conv2D)           (None, 256, 1, 32)           1056      ['max_pooling2d[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 1, 32)           3104      ['conv2d_7[0][0]']
#
#  add_4 (Add)                 (None, 256, 1, 32)           0         ['conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 1, 32)           3104      ['add_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 1, 32)           3104      ['conv2d_9[0][0]']
#
#  add_5 (Add)                 (None, 256, 1, 32)           0         ['add_4[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 256, 1, 32)           3104      ['add_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 256, 1, 32)           3104      ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 256, 1, 32)           3104      ['conv2d_12[0][0]']
#
#  add_6 (Add)                 (None, 256, 1, 32)           0         ['conv2d_10[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  add_7 (Add)                 (None, 256, 1, 32)           0         ['add_6[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 1, 32)           0         ['add_7[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 128, 1, 32)           1056      ['max_pooling2d_1[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_14[0][0]']
#
#  add_8 (Add)                 (None, 128, 1, 32)           0         ['conv2d_14[0][0]',
#                                                                      'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 1, 32)           3104      ['add_8[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_16[0][0]']
#
#  add_9 (Add)                 (None, 128, 1, 32)           0         ['add_8[0][0]',
#                                                                      'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 1, 32)           3104      ['add_9[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 128, 1, 32)           3104      ['conv2d_19[0][0]']
#
#  add_10 (Add)                (None, 128, 1, 32)           0         ['conv2d_17[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  add_11 (Add)                (None, 128, 1, 32)           0         ['add_10[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 1, 32)            0         ['add_11[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 64, 1, 32)            1056      ['max_pooling2d_2[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_21[0][0]']
#
#  add_12 (Add)                (None, 64, 1, 32)            0         ['conv2d_21[0][0]',
#                                                                      'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 1, 32)            3104      ['add_12[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_23[0][0]']
#
#  add_13 (Add)                (None, 64, 1, 32)            0         ['add_12[0][0]',
#                                                                      'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 64, 1, 32)            3104      ['add_13[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 1, 32)            3104      ['conv2d_26[0][0]']
#
#  add_14 (Add)                (None, 64, 1, 32)            0         ['conv2d_24[0][0]',
#                                                                      'conv2d_27[0][0]']
#
#  add_15 (Add)                (None, 64, 1, 32)            0         ['add_14[0][0]',
#                                                                      'conv2d_21[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 1, 32)            0         ['add_15[0][0]']
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 32, 1, 32)            1056      ['max_pooling2d_3[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_28[0][0]']
#
#  add_16 (Add)                (None, 32, 1, 32)            0         ['conv2d_28[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 32, 1, 32)            3104      ['add_16[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_30[0][0]']
#
#  add_17 (Add)                (None, 32, 1, 32)            0         ['add_16[0][0]',
#                                                                      'conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 32, 1, 32)            3104      ['add_17[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_32[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 32, 1, 32)            3104      ['conv2d_33[0][0]']
#
#  add_18 (Add)                (None, 32, 1, 32)            0         ['conv2d_31[0][0]',
#                                                                      'conv2d_34[0][0]']
#
#  add_19 (Add)                (None, 32, 1, 32)            0         ['add_18[0][0]',
#                                                                      'conv2d_28[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 1, 32)            0         ['add_19[0][0]']
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 16, 1, 32)            1056      ['max_pooling2d_4[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_35[0][0]']
#
#  add_20 (Add)                (None, 16, 1, 32)            0         ['conv2d_35[0][0]',
#                                                                      'conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 16, 1, 32)            3104      ['add_20[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_37[0][0]']
#
#  add_21 (Add)                (None, 16, 1, 32)            0         ['add_20[0][0]',
#                                                                      'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 16, 1, 32)            3104      ['add_21[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 16, 1, 32)            3104      ['conv2d_40[0][0]']
#
#  add_22 (Add)                (None, 16, 1, 32)            0         ['conv2d_38[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  add_23 (Add)                (None, 16, 1, 32)            0         ['add_22[0][0]',
#                                                                      'conv2d_35[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 1, 32)             0         ['add_23[0][0]']
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 8, 1, 32)             1056      ['max_pooling2d_5[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_42[0][0]']
#
#  add_24 (Add)                (None, 8, 1, 32)             0         ['conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 8, 1, 32)             3104      ['add_24[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_44[0][0]']
#
#  add_25 (Add)                (None, 8, 1, 32)             0         ['add_24[0][0]',
#                                                                      'conv2d_45[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 8, 1, 32)             3104      ['add_25[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_46[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 8, 1, 32)             3104      ['conv2d_47[0][0]']
#
#  add_26 (Add)                (None, 8, 1, 32)             0         ['conv2d_45[0][0]',
#                                                                      'conv2d_48[0][0]']
#
#  add_27 (Add)                (None, 8, 1, 32)             0         ['add_26[0][0]',
#                                                                      'conv2d_42[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 1, 32)             0         ['add_27[0][0]']
#  g2D)
#
#  flatten (Flatten)           (None, 128)                  0         ['max_pooling2d_6[0][0]']
#
#  dense (Dense)               (None, 128)                  16512     ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 6)                    774       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 172486 (673.77 KB)
# Trainable params: 172486 (673.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
X_train = np.load("DATASETS/X_train.npy",allow_pickle=True)
y_train_onehot = np.load("DATASETS/y_train_onehot.npy",allow_pickle=True)
y_test = np.load("DATASETS/y_test.npy",allow_pickle=True)
X_test = pd.read_hdf("DATASETS/test_data.h5",key="test")
# Out:
# /tmp/ipykernel_8380/2731762193.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_test = pd.read_hdf("DATASETS/test_data.h5",key="test")

# %%
X_train = X_train[:, :512, :]

# %%
import tensorflow_addons as tfa

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="checkpoints/",
    save_weights_only=True,
    monitor='val_f1_score',  # Changed from 'val_acc' to 'val_accuracy'
    mode='max',
    save_best_only=True)

# EarlyStopping callback to stop training when overfitting is detected
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=15,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True)  # Restore model weights from the epoch with the best value of the monitored quantity

model.compile(optimizer="adam",loss='categorical_crossentropy', metrics=[tfa.metrics.F1Score(num_classes=6, average='macro')])

batch_size = 1024
epochs = 150
history = model.fit(X_train, y_train_onehot, batch_size=batch_size, epochs=epochs,
                    callbacks=[tensorboard_callback, model_checkpoint_callback, early_stopping_callback],
                    validation_split=0.3)
# Out:
# /opt/saturncloud/envs/saturn/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2024-03-03 22:53:45.036434: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Epoch 1/150
# 2024-03-03 22:53:51.979068: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-03-03 22:53:52.067623: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-03 22:53:55.180050: I external/local_xla/xla/service/service.cc:168] XLA service 0x7eff79553f80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-03 22:53:55.180083: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-03-03 22:53:55.187382: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709506435.303986    8491 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 171/171 [==============================] - 65s 276ms/step - loss: 1.2052 - f1_score: 0.4811 - val_loss: 0.4109 - val_f1_score: 0.8183
# Epoch 2/150
# 171/171 [==============================] - 44s 256ms/step - loss: 0.3773 - f1_score: 0.8388 - val_loss: 0.3424 - val_f1_score: 0.8481
# Epoch 3/150
# 171/171 [==============================] - 44s 256ms/step - loss: 0.3303 - f1_score: 0.8575 - val_loss: 0.3134 - val_f1_score: 0.8630
# Epoch 4/150
# 171/171 [==============================] - 44s 257ms/step - loss: 0.3022 - f1_score: 0.8690 - val_loss: 0.3083 - val_f1_score: 0.8685
# Epoch 5/150
# 171/171 [==============================] - 44s 256ms/step - loss: 0.2899 - f1_score: 0.8745 - val_loss: 0.2830 - val_f1_score: 0.8760
# Epoch 6/150
# 171/171 [==============================] - 44s 256ms/step - loss: 0.2782 - f1_score: 0.8793 - val_loss: 0.2741 - val_f1_score: 0.8826
# Epoch 7/150
# 171/171 [==============================] - 44s 256ms/step - loss: 0.2653 - f1_score: 0.8851 - val_loss: 0.2662 - val_f1_score: 0.8858
# Epoch 8/150
# 171/171 [==============================] - 44s 256ms/step - loss: 0.2590 - f1_score: 0.8885 - val_loss: 0.2570 - val_f1_score: 0.8903
# Epoch 9/150
# 171/171 [==============================] - 43s 255ms/step - loss: 0.2527 - f1_score: 0.8921 - val_loss: 0.2654 - val_f1_score: 0.8872
# Epoch 10/150
# 171/171 [==============================] - 44s 255ms/step - loss: 0.2756 - f1_score: 0.8827 - val_loss: 0.2533 - val_f1_score: 0.8905
# Epoch 11/150
# 171/171 [==============================] - 44s 255ms/step - loss: 0.2417 - f1_score: 0.8966 - val_loss: 0.2521 - val_f1_score: 0.8940
# Epoch 12/150
# 171/171 [==============================] - 44s 255ms/step - loss: 0.2347 - f1_score: 0.8993 - val_loss: 0.2473 - val_f1_score: 0.8954
# Epoch 13/150
# 171/171 [==============================] - 44s 255ms/step - loss: 0.2291 - f1_score: 0.9029 - val_loss: 0.2434 - val_f1_score: 0.8987
# Epoch 14/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.2269 - f1_score: 0.9040 - val_loss: 0.2549 - val_f1_score: 0.8920
# Epoch 15/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.2236 - f1_score: 0.9048 - val_loss: 0.2477 - val_f1_score: 0.8960
# Epoch 16/150
# 171/171 [==============================] - 44s 255ms/step - loss: 0.2142 - f1_score: 0.9098 - val_loss: 0.2366 - val_f1_score: 0.9019
# Epoch 17/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.2178 - f1_score: 0.9078 - val_loss: 0.2551 - val_f1_score: 0.8933
# Epoch 18/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.2329 - f1_score: 0.9029 - val_loss: 0.2468 - val_f1_score: 0.8952
# Epoch 19/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.2159 - f1_score: 0.9093 - val_loss: 0.2380 - val_f1_score: 0.9006
# Epoch 20/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.2083 - f1_score: 0.9118 - val_loss: 0.2457 - val_f1_score: 0.8998
# Epoch 21/150
# 171/171 [==============================] - 44s 255ms/step - loss: 0.2010 - f1_score: 0.9153 - val_loss: 0.2286 - val_f1_score: 0.9049
# Epoch 22/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.2042 - f1_score: 0.9141 - val_loss: 0.2428 - val_f1_score: 0.9008
# Epoch 23/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.1981 - f1_score: 0.9168 - val_loss: 0.2347 - val_f1_score: 0.9047
# Epoch 24/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.2051 - f1_score: 0.9144 - val_loss: 0.2307 - val_f1_score: 0.9028
# Epoch 25/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.1880 - f1_score: 0.9205 - val_loss: 0.2351 - val_f1_score: 0.9038
# Epoch 26/150
# 171/171 [==============================] - 43s 254ms/step - loss: 0.1863 - f1_score: 0.9220 - val_loss: 0.2305 - val_f1_score: 0.9064
# Epoch 27/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.1834 - f1_score: 0.9236 - val_loss: 0.2395 - val_f1_score: 0.9048
# Epoch 28/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.1955 - f1_score: 0.9188 - val_loss: 0.2464 - val_f1_score: 0.9019
# Epoch 29/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.1865 - f1_score: 0.9224 - val_loss: 0.2331 - val_f1_score: 0.9048
# Epoch 30/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.2419 - f1_score: 0.9011 - val_loss: 0.2697 - val_f1_score: 0.8860
# Epoch 31/150
# 171/171 [==============================] - 43s 252ms/step - loss: 0.2183 - f1_score: 0.9075 - val_loss: 0.2411 - val_f1_score: 0.9003
# Epoch 32/150
# 171/171 [==============================] - 43s 252ms/step - loss: 0.1919 - f1_score: 0.9196 - val_loss: 0.2392 - val_f1_score: 0.9041
# Epoch 33/150
# 171/171 [==============================] - 43s 253ms/step - loss: 0.1783 - f1_score: 0.9258 - val_loss: 0.2320 - val_f1_score: 0.9076
# Epoch 34/150
# 171/171 [==============================] - 43s 251ms/step - loss: 0.1694 - f1_score: 0.9300 - val_loss: 0.2369 - val_f1_score: 0.9039
# Epoch 35/150
# 171/171 [==============================] - 43s 252ms/step - loss: 0.1723 - f1_score: 0.9285 - val_loss: 0.2359 - val_f1_score: 0.9042
# Epoch 36/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1667 - f1_score: 0.9310Restoring model weights from the end of the best epoch: 21.
# 171/171 [==============================] - 43s 252ms/step - loss: 0.1667 - f1_score: 0.9310 - val_loss: 0.2340 - val_f1_score: 0.9066
# Epoch 36: early stopping

# %%
model.save("TRSN_512.h5")
# Out:
# /opt/saturncloud/envs/saturn/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
